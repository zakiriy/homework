# %%
# Task 1
# Задание
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# Найдите их сумму. (на листочке)

# РЕШЕНИЕ:
# Сумма двух векторов = (10, 10, 10) + (0, 0, -10) = (10, 10, 0)

# %%
import numpy as np
a = int(input("Please enter X coordinate for vector = "))
b = int(input("Please enter Y coordinate for vector = "))
length = np.sqrt(a**2 + b**2)
print("Vector length = ", length)
# Out:
# Please enter X coordinate for vector = 3
# Please enter Y coordinate for vector = 4
# Vector length =  5.0

# %%
# Почему прямые не кажутся перпендикулярными? (см.ролик)
# ОТВЕТ: из-за несимметричности координат Х и У

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5, 5, 21)
y = 3*x+1
y2 = (-1/3)*x+1
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# TASK 3. Задание (в программе)
# Напишите код на Python, реализующий построение графиков:
# 1) окружности,
# 2) эллипса,
# 3) гиперболы.

# Окружность - Вариант 1
import turtle
import time

t = turtle.Turtle()
t.circle(60)
time.sleep(3)
quit()

# %%
# Окружность - Вариант 2
# %matplotlib inline
import matplotlib.pyplot as plt

circle = plt.Circle((0.5, 0.5), 0.5, color='red')
fig, ax = plt.subplots()
plt.gca().add_patch(circle)

# %%
# Окружность - Вариант 3

import matplotlib.pyplot as plt

plt.plot(4000, 4000, 'o', markersize=200)

# %%
# Окружность - Вариант 4

import matplotlib.pyplot as plt
import numpy as np

R = 1
n = 64
t = np.linspace(0, 2*np.pi, n+1)
x = R*np.cos(t)
y = R*np.sin(t)
plt.axis('equal')
plt.grid
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Эллипс - Вариант 1

import matplotlib.pyplot as plt
import numpy as np

n = 64
t = np.linspace(0, 2*np.pi, n+1)
x = 20*np.cos(t)
y = 10*np.sin(t)
plt.axis('equal')
plt.grid
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Гипербола - Вариант 1

x = []
x2 = []
y = []
y2 = []

for i in range(1000):
    a = 400
    b = 200
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))
       
plt.plot(x, y, color='r')
plt.plot(x, y2, color='r')
plt.plot(x2, y2, color='r')
plt.plot(x2, y, color='r')
plt.axis('scaled')
plt.show()

# %%
# TASK 4 - 1

# плоскость Ax+By+Cz=0 проходит через начало координат, так как
# точка "O" с координатами в(0;0;0) удовлетворяет данному уравнению.

# %%
# TASK 4 - 2

# Имея уравнение прямой мы знаем координаты 2-х точек A(x, y, z) & A1(x1,y1,z1),
# принадлежащих этой прямой, возьмем координаты этих точек и подставим в уравнение
# плоскости. Если при решении уравнения не выполняется равенство 
# значит прямая не принадлежит этой плоскости.
